# %% [markdown]
# # Section 8

# %% [markdown]
# ### Task 1: Discount Calculator

# %% [markdown]
# Build a program that calculates a discount based on the purchase amount and applies it if certain conditions are met (e.g., minimum purchase value).

# %%
purchase_amount = int(input("How much did you spend?"))

if purchase_amount >= 100:
  print("Congrats! You get $5 off your purchase")
else:
  print ("Would you like to shop more and get a discount?")
  needed_purchase_amount = 100 - purchase_amount
  print("If you spend $",needed_purchase_amount, "more, you'll get $5 off your purchase" )

#if purchase_amount < 100 :
  #print ("You can shop more and get a discount")


#your code ends here
# Out:
# How much did you spend?87
# Would you like to shop more and get a discount?
# If you spend $ 13 more, you'll get $5 off your purchase

# %% [markdown]
# ### Task 2: Age Verification

# %% [markdown]
# Write a Python script that not only checks if a person is eligible to vote but also provides additional information based on their age:
#
# If the age is less than 13, print a message that they are too young for most social media platforms.
# If the age is between 13 and 17 (inclusive), print a message about parental consent for social media usage.
# If the age is 18 or older, print a message about voting eligibility

# %%
age = int(input("How old are you?"))
if age >= 18:
  print("Congrats! You are eligible to vote.")
elif age < 13:
  print ("Sorry, you are too young to be on social media.")
elif 13 <= age <=17:

  print("You need parental consent to be on social media.")




#your code ends here
# Out:
# How old are you?11
# Sorry, you are too young to be on social media.

# %% [markdown]
# ### Task 3: Temperature Classifier

# %% [markdown]
# Create a Python program that classifies temperatures into different categories:
#
# Below freezing (less than 0 degrees Celsius)
# Mild (between 0 and 20 degrees Celsius)
# Warm (between 20 and 30 degrees Celsius)
# Hot (above 30 degrees Celsius)
# Prompt the user for the temperature and print the corresponding classification.

# %%
your_temperature = int(input("What is your temperature?"))


if your_temperature <= 0 :
  print("below freezing")

elif 0 < your_temperature <= 20 :
  print("mild")

elif 20 < your_temperature <= 30 :
  print("warm")

elif your_temperature > 30 :
  print ("hot")
#if your_temperature





#your code ends here
# Out:
# What is your temperature?0
# below freezing

# %% [markdown]
# ### Task 4: Find Packs

# %% [markdown]
# A shopkeeper has pack of 6 eggs and he sells eggs in packs, customer has to purchase number
# of packs according to their requirements. Write a program to input the number of eggs and print the
# minimum number of packs required by the customer.

# %% [markdown]
# Sample run:
#
# Eggs = 15
#
# packs = 3

# %%
eggs = int(input("How many eggs would you like to purchase?"))
packs = eggs//6
eggs_remainder = eggs%6

if eggs_remainder >= 1 :
  print(packs + 1, "packs needed to be purchased")

else :

  print(packs, "packs")



#your code ends here
# Out:
# How many eggs would you like to purchase?20
# 4 packs needed to be purchased

# %% [markdown]
# ### Task 5: Find leap year

# %% [markdown]
# Write a Python program that prompts the user to enter a year. The program should check if the year is a leap year. You can refer google to find how to check if a year is leap year or not.

# %%
# A year is a leap year if it's divisible by four, but not if it's divisible by both 100 and four

leap_year = int(input("What year would you like to check?"))



if leap_year/4 :
  print("leap year")

elif :

  print("not a leap year")

elif leap_year/4 and leap_year/100 :
  print("not a leap year")
# Out:
# What year would you like to check?2024
# leap year

# %% [markdown]
# ### Task 6: Vowel or Consonant

# %% [markdown]
# Write a Python program that prompts the user to enter a single letter. The program should check if the letter is a vowel (a, e, i, o, u) or a consonant and print the result. (hint: use membership operator)

# %%
vowel = ['a', 'e', 'i', 'o', 'u']

your_letter = input("What is your letter?")

if your_letter in vowel :
  print('vowel')
else :
  print('consonant')
# Out:
# What is your letter?b
# consonant
