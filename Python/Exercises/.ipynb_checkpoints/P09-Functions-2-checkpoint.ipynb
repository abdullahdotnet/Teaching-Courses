# %% [markdown]
# ## Task 1: Count Vowels in a String
#
# Write a function named `count_vowels` that takes a string as input and returns the number of vowels (a, e, i, o, u) in it. Make sure it works for both uppercase and lowercase letters.
#
# **Example:**
# ```python
# count_vowels("Hello World")  # Output: 3
# count_vowels("Python")       # Output: 1

# %% [markdown]
# ## Task 2: Find the Maximum of Three Numbers
#
# Write a function named `max_of_three` that takes three numbers as input and returns the largest of them.
#
# **Example:**
# ```python
# max_of_three(3, 7, 5)  # Output: 7
# max_of_three(-1, -4, -2)  # Output: -1

# %% [markdown]
# ## Task 3: Check if a Number is Prime
#
# Write a function named `is_prime` that checks if a given number is a prime number. A prime number is greater than 1 and divisible only by 1 and itself.
#
# **Example:**
# ```python
# is_prime(7)   # Output: True
# is_prime(10)  # Output: False

# %% [markdown]
# ## Task 4: Analyze Daily Steps
#
# You’re tracking your daily steps and want to analyze your progress. Write a function named `step_analysis` that takes a list of daily steps and:
# 1. Returns the total steps.
# 2. Returns the day with the highest number of steps.
#
# **Example:**
# ```python
# step_analysis([5000, 7000, 10000, 8000])  # Output: (30000, 3)

# %% [markdown]
# ## Task 4: Find the Best Deal
#
# You’re shopping online and comparing deals. Write a function named `best_deal` that takes:
# 1. A list of item prices.
# 2. A list of discounts (in percentages, same length as the price list).
#
# The function should return the price of the item with the lowest **final cost** after applying the discount.
#
# **Example:**
# ```python
# best_deal([100, 200, 150], [10, 20, 15])  # Output: 160.0
